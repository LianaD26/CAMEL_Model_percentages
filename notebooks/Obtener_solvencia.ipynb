# %%
import pandas as pd

# %%
data_solvencia = pd.read_excel("../tablas/registros_solvencia.xlsx")
data_solvencia
# Out:
# c:\Users\Liana\AppData\Local\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                                                    Fecha  Tipo entidad  \
# 0                                    2026-02-28 00:00:00           1.0
# 1                                    2026-02-28 00:00:00           1.0
# 2                                    2026-02-28 00:00:00           1.0
# 3                                    2026-02-28 00:00:00           1.0
# 4                                    2026-02-28 00:00:00           1.0
# ...                                                  ...           ...
# 20860                                2021-01-31 00:00:00           1.0
# 20861                                2021-01-31 00:00:00           1.0
# 20862                                2021-01-31 00:00:00           1.0
# 20863                                                NaN           NaN
# 20864  Filtros aplicados: \nConcepto es 01. Patrimoni...           NaN
#
#        Código entidad       Entidad  \
# 0                49.0     AV Villas
# 1                49.0     AV Villas
# 2                49.0     AV Villas
# 3                49.0     AV Villas
# 4                49.0     AV Villas
# ...               ...           ...
# 20860            62.0  Mibanco S.A.
# 20861            62.0  Mibanco S.A.
# 20862            62.0  Mibanco S.A.
# 20863             NaN           NaN
# 20864             NaN           NaN
#
#                                                 Concepto         Valor
# 0      01. Patrimonio Básico Ordinario Neto de Deducc...  1.224758e+06
# 1                  02. Patrimonio Básico Adicional (PBA)  1.756590e+02
# 2                          03. Patrimonio Adicional (PA)  2.372833e+05
# 3                                 04. Patrimonio Técnico  1.462217e+06
# 4      05. Total de Activos Ponderados por Nivel de R...  1.132087e+07
# ...                                                  ...           ...
# 20860                  10. Relación solvencia básica (%)  1.418280e+01
# 20861        11. Relación solvencia básica adicional (%)  1.418280e+01
# 20862                   12. Relación solvencia total (%)  1.531091e+01
# 20863                                                NaN           NaN
# 20864                                                NaN           NaN
#
# [20865 rows x 6 columns]

# %%
data_solvencia_bancos = data_solvencia[data_solvencia["Concepto"]=="10. Relación solvencia básica (%)"]
data_solvencia_bancos
# Out:
#                      Fecha  Tipo entidad  Código entidad  \
# 9      2026-02-28 00:00:00           1.0            49.0
# 21     2026-02-28 00:00:00           1.0            43.0
# 33     2026-02-28 00:00:00           1.0            52.0
# 45     2026-02-28 00:00:00           1.0            51.0
# 55     2026-02-28 00:00:00           1.0            66.0
# ...                    ...           ...             ...
# 20815  2021-01-31 00:00:00           1.0             9.0
# 20826  2021-01-31 00:00:00           1.0            58.0
# 20837  2021-01-31 00:00:00           1.0            55.0
# 20849  2021-01-31 00:00:00           1.0             6.0
# 20860  2021-01-31 00:00:00           1.0            62.0
#
#                           Entidad                           Concepto  \
# 9                       AV Villas  10. Relación solvencia básica (%)
# 21                     Banagrario  10. Relación solvencia básica (%)
# 33                  Bancamía S.A.  10. Relación solvencia básica (%)
# 45                        Bancien  10. Relación solvencia básica (%)
# 55     Banco BTG Pactual Colombia  10. Relación solvencia básica (%)
# ...                           ...                                ...
# 20815                    Citibank  10. Relación solvencia básica (%)
# 20826                 Coopcentral  10. Relación solvencia básica (%)
# 20837                   Finandina  10. Relación solvencia básica (%)
# 20849                        Itaú  10. Relación solvencia básica (%)
# 20860                Mibanco S.A.  10. Relación solvencia básica (%)
#
#            Valor
# 9       9.534518
# 21     17.532591
# 33     18.517132
# 45     11.936637
# 55     32.431069
# ...          ...
# 20815  26.475122
# 20826  25.971143
# 20837  27.953118
# 20849  10.724460
# 20860  14.182804
#
# [1792 rows x 6 columns]

# %%
data_solvencia_bancos = data_solvencia_bancos.drop(columns=["Tipo entidad", "Código entidad", "Concepto"])
data_solvencia_bancos
# Out:
#                      Fecha                     Entidad      Valor
# 9      2026-02-28 00:00:00                   AV Villas   9.534518
# 21     2026-02-28 00:00:00                  Banagrario  17.532591
# 33     2026-02-28 00:00:00               Bancamía S.A.  18.517132
# 45     2026-02-28 00:00:00                     Bancien  11.936637
# 55     2026-02-28 00:00:00  Banco BTG Pactual Colombia  32.431069
# ...                    ...                         ...        ...
# 20815  2021-01-31 00:00:00                    Citibank  26.475122
# 20826  2021-01-31 00:00:00                 Coopcentral  25.971143
# 20837  2021-01-31 00:00:00                   Finandina  27.953118
# 20849  2021-01-31 00:00:00                        Itaú  10.724460
# 20860  2021-01-31 00:00:00                Mibanco S.A.  14.182804
#
# [1792 rows x 3 columns]

# %%
data_solvencia_bancos.to_excel("registros_solvencia_organizados.xlsx")

# %% [markdown]
# ## Concatenar estos valores con los de IRL

# %%
# leer tabla completa del IRL
data = pd.read_excel("../tablas/registros_irl_actualizado.xlsx")
data
# Out:
#         Unnamed: 0  ID_registro                           ID_indicador  \
# 0                0            1                  Quebranto Patrimonial
# 1                1            2                  Quebranto Patrimonial
# 2                2            3                  Quebranto Patrimonial
# 3                3            4                  Quebranto Patrimonial
# 4                4            5                  Quebranto Patrimonial
# ...            ...          ...                                    ...
# 213305      216263       210138  Indicador de Riesgo de Liquidez - IRL
# 213306      216264       210139  Indicador de Riesgo de Liquidez - IRL
# 213307      216265       210140  Indicador de Riesgo de Liquidez - IRL
# 213308      216266       210141  Indicador de Riesgo de Liquidez - IRL
# 213309      216267       210142  Indicador de Riesgo de Liquidez - IRL
#
#                                            ID_cooperativa   ano  mes     valor
# 0                              CAJA COOPERATIVA CREDICOOP  2014    1  1.500449
# 1                              CAJA COOPERATIVA PETROLERA  2014    1  1.310736
# 2                              CASA NACIONAL DEL PROFESOR  2014    1  1.188087
# 3               COOPANTEX COOPERATIVA DE AHORRO Y CREDITO  2014    1  1.588034
# 4          COOPERATIVA AHORRO Y CREDITO GOMEZ PLATA LTDA.  2014    1  1.481415
# ...                                                   ...   ...  ...       ...
# 213305         COPROCENVA COOPERATIVA DE AHORRO Y CREDITO  2022   12  1.711657
# 213306  EMPRESA COOPERATIVA DE AHORRO Y CREDITO SIGLO ...  2022   12   2.96267
# 213307    FINANCIERA COOPERATIVA COLOMBIANA DE INGENIEROS  2022   12  2.701807
# 213308  GRAN COOPERATIVA DE ENERGIA ELECTRICA Y RECURS...  2022   12  1.614583
# 213309          MULTIACTIVA EL ROBLE, ENTIDAD COOPERATIVA  2022   12  2.701807
#
# [213310 rows x 7 columns]

# %%
data_matching = pd.read_excel("../tablas/df_matching.xlsx")
data_matching
# Out:
#      fecha_mes                                        cooperativa  \
# 0      2020-03  COOPERATIVA DE LOS PROFESIONALES DE LA SALUD C...
# 1      2020-03  COOPERATIVA DE AHORRO Y CREDITO PARA EL BIENES...
# 2      2020-03               COOPERATIVA PARA EL BIENESTAR SOCIAL
# 3      2020-03               COOPERATIVA FINANCIERA SAN FRANCISCO
# 4      2020-03  COOPERATIVA MULTIACTIVA DE LA AVIACION CIVIL C...
# ...        ...                                                ...
# 2953   2022-12                 COOPERATIVA BELEN AHORRO Y CREDITO
# 2954   2022-12     COOPERATIVA DE AHORRO Y CREDITO FINANCIAFONDOS
# 2955   2022-12  COOPERATIVA DE AHORRO Y CREDITO DE DROGUISTAS ...
# 2956   2022-12            COOPERATIVA DE AHORRO Y CREDITO COLANTA
# 2957   2022-12  COOPERATIVA ESPECIALIZADA DE AHORRO Y CREDITO ...
#
#         valor_coop         banco_mas_parecido   valor_banco     distancia  \
# 0     2.027045e+10                Bancolombia  1.851019e+10  1.760258e+09
# 1     8.144119e+09        Banco GNB Sudameris  7.452656e+09  6.914630e+08
# 2     7.102875e+09         Banco de Occidente  6.776300e+09  3.265745e+08
# 3     1.975291e+09                  AV Villas  1.813395e+09  1.618960e+08
# 4     3.293004e+09              Banco Popular  3.307329e+09  1.432539e+07
# ...            ...                        ...           ...           ...
# 2953  5.395926e+09  Scotiabank Colpatria S.A.  5.385472e+09  1.045359e+07
# 2954  2.809681e+08               Mibanco S.A.  2.803724e+08  5.956302e+05
# 2955  1.269489e+10              BBVA Colombia  1.288028e+10  1.853855e+08
# 2956  8.335767e+09        Banco GNB Sudameris  8.814007e+09  4.782395e+08
# 2957  5.468121e+08       Banco Pichincha S.A.  5.251730e+08  2.163916e+07
#
#                  Nombre Entidad       IRL
# 0                   Bancolombia     2.443
# 1           Banco GNB Sudameris     2.426
# 2            Banco de Occidente     2.317
# 3                     AV Villas     1.273
# 4                 Banco Popular     1.591
# ...                         ...       ...
# 2953  Scotiabank Colpatria S.A.  3.700938
# 2954               Mibanco S.A.  2.354543
# 2955              BBVA Colombia  1.696709
# 2956        Banco GNB Sudameris  2.015326
# 2957       Banco Pichincha S.A.  1.516988
#
# [2958 rows x 8 columns]

# %%
# Convertir el formato de fecha de data_solvencia_bancos a formato YYYY-MM
data_solvencia_bancos['Fecha'] = pd.to_datetime(data_solvencia_bancos['Fecha'])
data_solvencia_bancos['fecha_mes'] = data_solvencia_bancos['Fecha'].dt.strftime('%Y-%m')

# Renombrar la columna Entidad a Nombre Entidad para que coincida con data_matching
data_solvencia_bancos_renamed = data_solvencia_bancos[['fecha_mes', 'Entidad', 'Valor']].copy()
data_solvencia_bancos_renamed = data_solvencia_bancos_renamed.rename(columns={'Entidad': 'Nombre Entidad', 'Valor': 'Solvencia'})

# Hacer merge de los dataframes donde coincidan la fecha y el nombre del banco
data_matching_con_solvencia = data_matching.merge(
    data_solvencia_bancos_renamed,
    on=['fecha_mes', 'Nombre Entidad'],
    how='left'
)

data_matching_con_solvencia
# Out:
#      fecha_mes                                        cooperativa  \
# 0      2020-03  COOPERATIVA DE LOS PROFESIONALES DE LA SALUD C...
# 1      2020-03  COOPERATIVA DE AHORRO Y CREDITO PARA EL BIENES...
# 2      2020-03               COOPERATIVA PARA EL BIENESTAR SOCIAL
# 3      2020-03               COOPERATIVA FINANCIERA SAN FRANCISCO
# 4      2020-03  COOPERATIVA MULTIACTIVA DE LA AVIACION CIVIL C...
# ...        ...                                                ...
# 2953   2022-12                 COOPERATIVA BELEN AHORRO Y CREDITO
# 2954   2022-12     COOPERATIVA DE AHORRO Y CREDITO FINANCIAFONDOS
# 2955   2022-12  COOPERATIVA DE AHORRO Y CREDITO DE DROGUISTAS ...
# 2956   2022-12            COOPERATIVA DE AHORRO Y CREDITO COLANTA
# 2957   2022-12  COOPERATIVA ESPECIALIZADA DE AHORRO Y CREDITO ...
#
#         valor_coop         banco_mas_parecido   valor_banco     distancia  \
# 0     2.027045e+10                Bancolombia  1.851019e+10  1.760258e+09
# 1     8.144119e+09        Banco GNB Sudameris  7.452656e+09  6.914630e+08
# 2     7.102875e+09         Banco de Occidente  6.776300e+09  3.265745e+08
# 3     1.975291e+09                  AV Villas  1.813395e+09  1.618960e+08
# 4     3.293004e+09              Banco Popular  3.307329e+09  1.432539e+07
# ...            ...                        ...           ...           ...
# 2953  5.395926e+09  Scotiabank Colpatria S.A.  5.385472e+09  1.045359e+07
# 2954  2.809681e+08               Mibanco S.A.  2.803724e+08  5.956302e+05
# 2955  1.269489e+10              BBVA Colombia  1.288028e+10  1.853855e+08
# 2956  8.335767e+09        Banco GNB Sudameris  8.814007e+09  4.782395e+08
# 2957  5.468121e+08       Banco Pichincha S.A.  5.251730e+08  2.163916e+07
#
#                  Nombre Entidad       IRL  Solvencia
# 0                   Bancolombia     2.443        NaN
# 1           Banco GNB Sudameris     2.426        NaN
# 2            Banco de Occidente     2.317        NaN
# 3                     AV Villas     1.273        NaN
# 4                 Banco Popular     1.591        NaN
# ...                         ...       ...        ...
# 2953  Scotiabank Colpatria S.A.  3.700938        NaN
# 2954               Mibanco S.A.  2.354543  16.108762
# 2955              BBVA Colombia  1.696709   8.702817
# 2956        Banco GNB Sudameris  2.015326  10.458678
# 2957       Banco Pichincha S.A.  1.516988  10.723143
#
# [2958 rows x 9 columns]

# %%
# Reemplazar valores NaN con 0.0 en la columna Solvencia
data_matching_con_solvencia['Solvencia'] = data_matching_con_solvencia['Solvencia'].fillna(0.0)

# Verificar el resultado
print("Verificación final:")
print(f"Valores no nulos: {data_matching_con_solvencia['Solvencia'].notna().sum()}")
print(f"Valores que son 0.0: {(data_matching_con_solvencia['Solvencia'] == 0.0).sum()}")
print(f"\nMuestra de resultados:")
print(data_matching_con_solvencia[['fecha_mes', 'Nombre Entidad', 'Solvencia']].head(20))
# Out:
# Verificación final:
# Valores no nulos: 2958
# Valores que son 0.0: 1056
#
# Muestra de resultados:
#    fecha_mes          Nombre Entidad  Solvencia
# 0    2020-03             Bancolombia        0.0
# 1    2020-03     Banco GNB Sudameris        0.0
# 2    2020-03      Banco de Occidente        0.0
# 3    2020-03               AV Villas        0.0
# 4    2020-03           Banco Popular        0.0
# 5    2020-03        Banco Davivienda        0.0
# 6    2020-03           Banco Popular        0.0
# 7    2020-03         Banco Santander        0.0
# 8    2020-03  Banco Caja Social S.A.        0.0
# 9    2020-03             Bancolombia        0.0
# 10   2020-03         Banco Santander        0.0
# 11   2020-03           Banco Popular        0.0
# 12   2020-03        Banco Davivienda        0.0
# 13   2020-03               AV Villas        0.0
# 14   2020-03     Banco GNB Sudameris        0.0
# 15   2020-03  Banco Caja Social S.A.        0.0
# 16   2020-03             Bancolombia        0.0
# 17   2020-03      Banco de Occidente        0.0
# 18   2020-03      Banco de Occidente        0.0
# 19   2020-03  Banco Caja Social S.A.        0.0

# %%
data_matching_con_solvencia[data_matching_con_solvencia["fecha_mes"]=="2021-03"]
# Out:
#      fecha_mes                                        cooperativa  \
# 1044   2021-03  COOPERATIVA DE LOS PROFESIONALES DE LA SALUD C...
# 1045   2021-03  COOPERATIVA DE AHORRO Y CREDITO PARA EL BIENES...
# 1046   2021-03               COOPERATIVA PARA EL BIENESTAR SOCIAL
# 1047   2021-03               COOPERATIVA FINANCIERA SAN FRANCISCO
# 1048   2021-03  COOPERATIVA MULTIACTIVA DE LA AVIACION CIVIL C...
# ...        ...                                                ...
# 1126   2021-03                 COOPERATIVA BELEN AHORRO Y CREDITO
# 1127   2021-03     COOPERATIVA DE AHORRO Y CREDITO FINANCIAFONDOS
# 1128   2021-03  COOPERATIVA DE AHORRO Y CREDITO DE DROGUISTAS ...
# 1129   2021-03            COOPERATIVA DE AHORRO Y CREDITO COLANTA
# 1130   2021-03  COOPERATIVA ESPECIALIZADA DE AHORRO Y CREDITO ...
#
#         valor_coop      banco_mas_parecido   valor_banco     distancia  \
# 1044  2.935153e+10             Bancolombia  2.131504e+10  8.036492e+09
# 1045  2.232013e+10             Bancolombia  2.131504e+10  1.005084e+09
# 1046  9.476965e+09           BBVA Colombia  9.782352e+09  3.053874e+08
# 1047  3.489560e+09               AV Villas  3.614583e+09  1.250221e+08
# 1048  1.970560e+09  Banco Caja Social S.A.  2.413999e+09  4.434397e+08
# ...            ...                     ...           ...           ...
# 1126  2.424982e+10             Bancolombia  2.131504e+10  2.934778e+09
# 1127  4.227716e+09           Banco Popular  4.263899e+09  3.618351e+07
# 1128  3.052693e+10             Bancolombia  2.131504e+10  9.211890e+09
# 1129  2.327256e+10             Bancolombia  2.131504e+10  1.957515e+09
# 1130  8.835591e+08         Banco Santander  8.702687e+08  1.329040e+07
#
#               Nombre Entidad    IRL  Solvencia
# 1044             Bancolombia  2.036  14.718009
# 1045             Bancolombia  2.036  14.718009
# 1046           BBVA Colombia  2.038   9.531233
# 1047               AV Villas  2.046  12.608449
# 1048  Banco Caja Social S.A.  5.186  18.066918
# ...                      ...    ...        ...
# 1126             Bancolombia  2.036  14.718009
# 1127           Banco Popular   1.64  11.481133
# 1128             Bancolombia  2.036  14.718009
# 1129             Bancolombia  2.036  14.718009
# 1130         Banco Santander  1.866  13.408436
#
# [87 rows x 9 columns]

# %% [markdown]
# ## Concatenar con la tabla general de todos los indicadores

# %%
df_coperativas = pd.read_excel("../tablas/registros.xlsx")
df_coperativas
# Out:
#         ID_registro                           ID_indicador  \
# 0                 1                  Quebranto Patrimonial
# 1                 2                  Quebranto Patrimonial
# 2                 3                  Quebranto Patrimonial
# 3                 4                  Quebranto Patrimonial
# 4                 5                  Quebranto Patrimonial
# ...             ...                                    ...
# 213305       213306  Indicador de Riesgo de Liquidez - IRL
# 213306       213307  Indicador de Riesgo de Liquidez - IRL
# 213307       213308  Indicador de Riesgo de Liquidez - IRL
# 213308       213309  Indicador de Riesgo de Liquidez - IRL
# 213309       213310  Indicador de Riesgo de Liquidez - IRL
#
#                                            ID_cooperativa   ano  mes     valor
# 0                              CAJA COOPERATIVA CREDICOOP  2014    1  1.500449
# 1                              CAJA COOPERATIVA PETROLERA  2014    1  1.310736
# 2                              CASA NACIONAL DEL PROFESOR  2014    1  1.188087
# 3               COOPANTEX COOPERATIVA DE AHORRO Y CREDITO  2014    1  1.588034
# 4          COOPERATIVA AHORRO Y CREDITO GOMEZ PLATA LTDA.  2014    1  1.481415
# ...                                                   ...   ...  ...       ...
# 213305         COPROCENVA COOPERATIVA DE AHORRO Y CREDITO  2025   12  0.000000
# 213306  EMPRESA COOPERATIVA DE AHORRO Y CREDITO SIGLO ...  2025   12  0.000000
# 213307    FINANCIERA COOPERATIVA COLOMBIANA DE INGENIEROS  2025   12  0.000000
# 213308  GRAN COOPERATIVA DE ENERGIA ELECTRICA Y RECURS...  2025   12  0.000000
# 213309          MULTIACTIVA EL ROBLE, ENTIDAD COOPERATIVA  2025   12  0.000000
#
# [213310 rows x 6 columns]

# %%
data_matching_con_solvencia["fecha_mes"] = data_matching_con_solvencia["fecha_mes"].astype(str)

data_matching_con_solvencia["ano"] = data_matching_con_solvencia["fecha_mes"].str[:4].astype(int)
data_matching_con_solvencia["mes"] = data_matching_con_solvencia["fecha_mes"].str[5:7].astype(int)

# %%
df_coop_solv = df_coperativas[
    df_coperativas["ID_indicador"] == "Relación Solvencia"
].copy()

# %%
df_merge = pd.merge(
    df_coop_solv,
    data_matching_con_solvencia[["cooperativa", "ano", "mes", "Solvencia"]],
    left_on=["ID_cooperativa", "ano", "mes"],
    right_on=["cooperativa", "ano", "mes"],
    how="inner"   
)

# %%
df_merge = df_merge.drop(["cooperativa", "valor"], axis=1)

# %%
df_merge = df_merge.rename(columns={"Solvencia": "valor"})

# %%
df_merge
# Out:
#       ID_registro        ID_indicador  \
# 0           26137  Relación Solvencia
# 1           26138  Relación Solvencia
# 2           26139  Relación Solvencia
# 3           26140  Relación Solvencia
# 4           26141  Relación Solvencia
# ...           ...                 ...
# 2953        37836  Relación Solvencia
# 2954        37837  Relación Solvencia
# 2955        37838  Relación Solvencia
# 2956        37839  Relación Solvencia
# 2957        37840  Relación Solvencia
#
#                                          ID_cooperativa   ano  mes      valor
# 0                            CAJA COOPERATIVA CREDICOOP  2020    3   0.000000
# 1                            CAJA COOPERATIVA PETROLERA  2020    3   0.000000
# 2                            CASA NACIONAL DEL PROFESOR  2020    3   0.000000
# 3             COOPANTEX COOPERATIVA DE AHORRO Y CREDITO  2020    3   0.000000
# 4        COOPERATIVA AHORRO Y CREDITO GOMEZ PLATA LTDA.  2020    3   0.000000
# ...                                                 ...   ...  ...        ...
# 2953         COPROCENVA COOPERATIVA DE AHORRO Y CREDITO  2022   12  10.222854
# 2954  EMPRESA COOPERATIVA DE AHORRO Y CREDITO SIGLO ...  2022   12   0.000000
# 2955    FINANCIERA COOPERATIVA COLOMBIANA DE INGENIEROS  2022   12  16.407932
# 2956  GRAN COOPERATIVA DE ENERGIA ELECTRICA Y RECURS...  2022   12  50.678016
# 2957          MULTIACTIVA EL ROBLE, ENTIDAD COOPERATIVA  2022   12  16.407932
#
# [2958 rows x 6 columns]

# %%
df_total = pd.concat([df_coperativas, df_merge], ignore_index=True)

# %%
df_total = df_total.drop_duplicates(
    subset=["ano", "mes", "ID_indicador", "ID_cooperativa"],
    keep="last"
)

# %%
df_total
# Out:
#         ID_registro           ID_indicador  \
# 0                 1  Quebranto Patrimonial
# 1                 2  Quebranto Patrimonial
# 2                 3  Quebranto Patrimonial
# 3                 4  Quebranto Patrimonial
# 4                 5  Quebranto Patrimonial
# ...             ...                    ...
# 216263        37836     Relación Solvencia
# 216264        37837     Relación Solvencia
# 216265        37838     Relación Solvencia
# 216266        37839     Relación Solvencia
# 216267        37840     Relación Solvencia
#
#                                            ID_cooperativa   ano  mes  \
# 0                              CAJA COOPERATIVA CREDICOOP  2014    1
# 1                              CAJA COOPERATIVA PETROLERA  2014    1
# 2                              CASA NACIONAL DEL PROFESOR  2014    1
# 3               COOPANTEX COOPERATIVA DE AHORRO Y CREDITO  2014    1
# 4          COOPERATIVA AHORRO Y CREDITO GOMEZ PLATA LTDA.  2014    1
# ...                                                   ...   ...  ...
# 216263         COPROCENVA COOPERATIVA DE AHORRO Y CREDITO  2022   12
# 216264  EMPRESA COOPERATIVA DE AHORRO Y CREDITO SIGLO ...  2022   12
# 216265    FINANCIERA COOPERATIVA COLOMBIANA DE INGENIEROS  2022   12
# 216266  GRAN COOPERATIVA DE ENERGIA ELECTRICA Y RECURS...  2022   12
# 216267          MULTIACTIVA EL ROBLE, ENTIDAD COOPERATIVA  2022   12
#
#             valor
# 0        1.500449
# 1        1.310736
# 2        1.188087
# 3        1.588034
# 4        1.481415
# ...           ...
# 216263  10.222854
# 216264   0.000000
# 216265  16.407932
# 216266  50.678016
# 216267  16.407932
#
# [213310 rows x 6 columns]

# %%
df_total.to_excel("registros_solvencia_actualizado.xlsx")
