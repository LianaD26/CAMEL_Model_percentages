# %%
import pandas as pd

# %%
datos=pd.read_csv("Registros_CAMEL_sin_solvencia_categorizados.csv")
datos.head()
# Out:
#    ID_registro   ano  mes                                       ID_indicador  \
# 0            1  2022    1                              Quebranto Patrimonial
# 1            3  2022    1  Relación entre Aportes sociales mínimos no red...
# 2            4  2022    1  Relación entre el Capital Institucional y el A...
# 3            5  2022    2                              Quebranto Patrimonial
# 4            7  2022    2  Relación entre Aportes sociales mínimos no red...
#
#                             ID_cooperativa     valor categoria
# 0  AVANCOP COOPERATIVA DE AHORRO Y CREDITO  1.265719   Micro 1
# 1  AVANCOP COOPERATIVA DE AHORRO Y CREDITO  0.431216   Micro 1
# 2  AVANCOP COOPERATIVA DE AHORRO Y CREDITO  0.067410   Micro 1
# 3  AVANCOP COOPERATIVA DE AHORRO Y CREDITO  1.270411   Micro 1
# 4  AVANCOP COOPERATIVA DE AHORRO Y CREDITO  0.430248   Micro 1

# %%
datos.to_excel("Registros_CAMEL_sin_solvencia_categorizados.xlsx",index=False)
