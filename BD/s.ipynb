# %%
import pandas as pd
import numpy as np

# %%
datos=pd.read_csv("Registros_CAMEL_sin_solvencia_categorizados.csv")
datos
# Out:
#         ID_registro   ano  mes  \
# 0                 1  2021    1
# 1                 3  2021    1
# 2                 4  2021    1
# 3                 5  2021    2
# 4                 7  2021    2
# ...             ...   ...  ...
# 132199       140480  2025    8
# 132200       140481  2025    9
# 132201       140482  2025   10
# 132202       140483  2025   11
# 132203       140484  2025   12
#
#                                              ID_indicador  \
# 0                                   Quebranto Patrimonial
# 1       Relación entre Aportes sociales mínimos no red...
# 2       Relación entre el Capital Institucional y el A...
# 3                                   Quebranto Patrimonial
# 4       Relación entre Aportes sociales mínimos no red...
# ...                                                   ...
# 132199  Activos líquidos ampliados / depósitos a corto...
# 132200  Activos líquidos ampliados / depósitos a corto...
# ...
